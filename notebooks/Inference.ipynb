# %%
# !pip install -Uqq fastai

# %%
from fastai.vision.all import *

# %%
# %cd /content/drive/MyDrive/Vispol_classify
# Out:
# /content/drive/MyDrive/Vispol_classify

# %%
version = 0
img_path = 'test_images'
model_path = f'models/vispol-1-recognizer-v{version}.pkl'

# %%
model = load_learner(model_path)

# %%
img = Image.open(f'{img_path}/streetLitters2-118.jpg')
img.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
model.predict(f'{img_path}/streetLitters2-118.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('street litter',
#  TensorBase(8),
#  TensorBase([3.5673e-07, 1.0312e-04, 2.6571e-05, 5.4175e-05, 7.9783e-07,
#              2.3071e-05, 2.5862e-05, 1.0087e-04, 9.9967e-01]))

# %%
img = Image.open(f'{img_path}/streetLitters2-218.jpg')
img.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
model.predict(f'{img_path}/streetLitters2-218.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('street litter',
#  TensorBase(8),
#  TensorBase([1.6233e-05, 2.0287e-06, 4.5801e-04, 1.0868e-05, 8.8324e-06,
#              1.6460e-04, 2.4274e-05, 1.9807e-05, 9.9930e-01]))

# %%
img = Image.open(f'{img_path}/towers-64.jpg')
img.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
model.predict(f'{img_path}/towers-64.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('antennas',
#  TensorBase(0),
#  TensorBase([0.4363, 0.0173, 0.0080, 0.0660, 0.0397, 0.0022, 0.0062, 0.4213,
#              0.0030]))

# %%
img = Image.open(f'{img_path}/BILLBOARDLAWSUIT-1-scaled.jpg')
img.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=256x171>

# %%
model.predict(f'{img_path}/BILLBOARDLAWSUIT-1-scaled.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('billboard',
#  TensorBase(1),
#  TensorBase([1.6427e-07, 1.0000e+00, 9.3529e-10, 2.1515e-07, 1.3351e-07,
#              1.6150e-07, 1.2000e-07, 3.3542e-06, 1.0386e-07]))

# %%
img = Image.open(f'{img_path}/poles.jpg')
img.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=170x256>

# %%
model.predict(f'{img_path}/poles.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('electric pole',
#  TensorBase(4),
#  TensorBase([1.6638e-03, 4.9399e-05, 1.2131e-06, 8.7822e-04, 9.9739e-01,
#              2.2139e-06, 4.2402e-06, 5.0491e-06, 1.4773e-06]))
